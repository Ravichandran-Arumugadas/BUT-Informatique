# %% [raw]
#                                     LE NOTEBOOK LIÉ À L ANALYSE DES QUESTIONS.
#
#
#
# -----Question préliminaire : Modélisation d’un réseau par un tableau
#
# Pour répondre à cette question, on a effectué le tableau sur une feuille, un brouillon afin de mieux se repérer.
# On a donc modéliser chaque interaction de chaque personne sur une feuille afin de mieux traiter la question.
# Et donc les interactions se caractérisaient tel que amis[2*1] a des intéractions avec amis[2*1+1].
# En soit, la question était plutôt simple à traiter mais on avait du mal à se répérer sur un ordinateur, c'est la raison
# pour laquelle on a commencé à traiter la question sur une feuille.
# De plus, en analysant l'exemple donnée avec le tableau amis, nous avons effectué la même pour construire
# un tableau p_amis et donc on a eu plus de facilités.
#
#
# -----Question 1 : Nombres d’amis d’une personne
# On a tout d'abord analyser la question par étape.
# De plus, on comprend juste en lisant la question qu'il y'aura une boucle car il faut parcourir le tableau qui
# modélise le réseau d'intéraction pour savoir le nombre d'amis d'une personne.
# Ainsi, étant donné que les intéractions du réseau se caractérisent tel que amis[2*1] a des interactions avec amis[2*1+1],
# si le prénom appararait une fois, cela veut dire qu'il a une intéraction. On s'est donc dit qu'à chacune des fois que le
# prénom apparait dans le tableau, la personne a un lien d'amitié avec une personne.
# On a donc créer une variable compteur et si au cours du parcours du tableau qui modélise les interactions,
# le prénom correspond au prénom émis en tant que paramètre de la fonction alors on ajoute +1 à compteur.
# Et donc, à la fin, on aura le nombre d’amis de prénom à partir des données du tableau amis.
#
# -----Question 2 : Nombre de membres d’un réseau social
# On a tout d'abord analyser la question par étape tout comme pour la première question.
# De plus, on comprend juste en lisant la question qu'il y'aura une boucle car il faut parcourir le tableau qui
# modélise le réseau d'intéraction pour savoir le nombre de personnes disctinctes du réseau, donc while.
# On a pris un peu plus de temps pour cette question car on l'avait trouvé complexe. C'est à la fin qu'on a eu l'idée
# de créer un tableau où il y aura toutes les personnes disctinctes pour à la fin retourner la longueur du tableau
# pour dire le nombre de personnes distinctes. Et donc dans le tableau, on ajouté le prénom d'une personne et pour ne pas ajouter le même prénom, on utilise une condition si le prénom est déjà dans le tableau, on ne l'ajoute pas(condition if not in).
#
#
#
# -----Question 3 : Lecture des données d’un réseau social à partir d’un fichier
# Cette question a été plutôt simple pour nous car en cours on avait vu plusieurs exemples de ce genre.
# La seule question qu'on s'est posé, c'était de savoir si on utilisait la fonction readlines ou readline.
# Mais on a trouvé  qu'avec la fonction readlines, c'était plus simple. Il fallait faire attention car il faut mettre la fonction
# split et strip sinon il y aurait eu toujours le séparateur ";" et il y aura eu plusieurs tableaux.
# On a ensuite créer un tableau pour ajouter chaque prénom du lien d'interaction(append).
#
#
# -----Question 4 : Modélisation d’un réseau par un dictionnaire
# Cette question a été la question la plus compliqué. En effet, il faut faire des boucles imbriquées.
# Et donc, on avait beaucoup de mal à l'éxécuter. Et donc dans un premier temps, on a refait les exercices de base
# sur les boucles imbriquées vu en cours. Et donc on eu un peu plus de facilités car avec une concentration , on a réussi.
# Et donc, on avait effectué chaque boucle étape par étape de la fonction pour à la fin les regrouper. Il ne fallait pas qu'on
# écrit la fonction du début jusqu'à la fin ligne par ligne mais plutôt décortiquer, analyser la consigne pour à la fin
# écrire chaque boucle correspondant à la fonction et ensuite les regrouper.
#
#
# -----Question 5 : Nombre d’amis des personnes les plus populaires
# Cette question a été plutôt simple, on avait fait beaucoup d'exercices de ce genre en cours et on a été plutôt à l'aise.
# Mais pour écrire cette fonction, il y avait plusieurs méthodes car on avait essayé de plusieurs manières et
# la fonction qu'on a écrit était la moins longue. On a décidé de créer une variable valeur qui représente les
# valeurs du dictionnaire ( utilisationt values() ). On avait juste à parcourir ce tableau valeurs pour savoir le nombre
# d'amis populaire.
#
# -----Question 6 : Personnes les plus populaires
# Pour cette question, on s’est aidé de la question 5. Dans la question, on a retourné le nombre d’amis des personnes
# les plus populaires et ici, on doit retourner dans un tableau les personnes les plus populaires du réseau.
# L'idée venait de la question précédente et donc on a réussit à l'éffectuer. On s'était juste demandé comment mettre
# les prénoms des personnes les plus populaires car dans la question précédente, il fallait juste donner un nombre.
# En plus, il fallait prendre en compte que plusieurs personnes pouvaient être populaires.
# Et donc, en analaysant la fonction, on s'est rendu compte qu'il fallait faire des conditions. On a donc utilisé if et elif
# pour répondre à cette question.
